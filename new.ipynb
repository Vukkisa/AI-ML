# %%
# To check exising environment variables

import os

for name, value in os.environ.items():
    print(f"{name} = {value}")
# Out:
# COMMAND_MODE = unix2003
# CONDA_DEFAULT_ENV = base
# CONDA_EXE = /opt/anaconda3/bin/conda
# CONDA_PREFIX = /opt/anaconda3
# CONDA_PROMPT_MODIFIER = (base)
# CONDA_PYTHON_EXE = /opt/anaconda3/bin/python
# CONDA_SHLVL = 1
# GSETTINGS_SCHEMA_DIR = /opt/anaconda3/share/glib-2.0/schemas
# HOME = /Users/vj
# HOMEBREW_CELLAR = /opt/homebrew/Cellar
# HOMEBREW_PREFIX = /opt/homebrew
# HOMEBREW_REPOSITORY = /opt/homebrew
# INFOPATH = /opt/homebrew/share/info:
# LANG = C.UTF-8
# LOGNAME = vj
# MANPATH = /opt/homebrew/share/man::
# MallocNanoZone = 0
# OLDPWD = /
# ORIGINAL_XDG_CURRENT_DESKTOP = undefined
# OSLogRateLimit = 64
# ...

# %%
if 'GOOGLE_API_KEY' not in os.environ:
    os.environ['GOOGLE_API_KEY'] ='AIzaSyDwcXOje45ln8ScNQZvK3HxOhD8CQsAPJ8'

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")
print(api_key)
# Out:
# AIzaSyDwcXOje45ln8ScNQZvK3HxOhD8CQsAPJ8

# %%
import google.generativeai as genai

model = genai.GenerativeModel('gemini-1.5-flash')

# Provide a sample user question
sample_question = "What are the benefits of using AI in business?"

# Generate a response
response = model.generate_content(sample_question)

# Print the chatbot's reply
print("Gemini Reply:", response.text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 import google.generativeai as genai
#       3 model = genai.GenerativeModel('gemini-1.5-flash')
#       5 # Provide a sample user question
#
# ModuleNotFoundError: No module named 'google.generativeai'

# %%
# !pip install -q google-genai

# %%
from google import genai

client = genai.Client(api_key="")  # or rely on GEMINI_API_KEY env var

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What are the benefits of using AI in business?",
)

print("Gemini reply:", response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[38], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key="YOUR_API_KEY")  # or rely on GEMINI_API_KEY env var
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash",
#       7     contents="What are the benefits of using AI in business?",
#       8 )
#      10 print("Gemini reply:", response.text)
#
# File ~/Desktop/AI-ML/env/lib/python3.11/site-packages/google/genai/models.py:5218, in Models.generate_content(self, model, contents, config)
#    5216 while remaining_remote_calls_afc > 0:
#    5217   i += 1
# -> 5218   response = self._generate_content(
#    5219       model=model, contents=contents, config=parsed_config
#    5220   )
#    5222   function_map = _extra_utils.get_function_map(parsed_config)
#    5223   if not function_map:
#
# ...

# %%
os.environ['MY_CUSTOM_ENV'] = 'my_value'
os.environ.values()
# Out:
# ValuesView(environ({'COMMAND_MODE': 'unix2003', 'CONDA_DEFAULT_ENV': 'base', 'CONDA_EXE': '/opt/anaconda3/bin/conda', 'CONDA_PREFIX': '/opt/anaconda3', 'CONDA_PROMPT_MODIFIER': '(base) ', 'CONDA_PYTHON_EXE': '/opt/anaconda3/bin/python', 'CONDA_SHLVL': '1', 'GSETTINGS_SCHEMA_DIR': '/opt/anaconda3/share/glib-2.0/schemas', 'HOME': '/Users/vj', 'HOMEBREW_CELLAR': '/opt/homebrew/Cellar', 'HOMEBREW_PREFIX': '/opt/homebrew', 'HOMEBREW_REPOSITORY': '/opt/homebrew', 'INFOPATH': '/opt/homebrew/share/info:', 'LANG': 'C.UTF-8', 'LOGNAME': 'vj', 'MANPATH': '/opt/homebrew/share/man::', 'MallocNanoZone': '0', 'OLDPWD': '/', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OSLogRateLimit': '64', 'PATH': '/Users/vj/Desktop/AI-ML/env/bin:/opt/anaconda3/bin:/opt/anaconda3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/Library/Frameworks/Python.framework/Versions/3.11/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/u
# ...

# %%
from google import genai
from google.genai import TextGenerationServiceClient
cilent=genai.TextGenerationServiceClient(model="gemini-1.5-flash")
cilent=genai.TextGenerationServiceClient()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 from google import genai
# ----> 2 from google.genai import TextGenerationServiceClient
#       3 cilent=genai.TextGenerationServiceClient(model="gemini-1.5-flash")
#       4 cilent=genai.TextGenerationServiceClient()
#
# ImportError: cannot import name 'TextGenerationServiceClient' from 'google.genai' (/Users/vj/Desktop/AI-ML/env/lib/python3.11/site-packages/google/genai/__init__.py)

# %%
from google import genai
from google.genai.types import HttpOptions

client = genai.Client(http_options=HttpOptions(api_version="v1"))
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Write a haiku about Python programming."
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 from google import genai
#       2 from google.genai.types import HttpOptions
# ----> 4 client = genai.Client(http_options=HttpOptions(api_version="v1"))
#       5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash",
#       7     contents="Write a haiku about Python programming."
#       8 )
#       9 print(response.text)
#
# File ~/Desktop/AI-ML/env/lib/python3.11/site-packages/google/genai/client.py:271, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     268   else:
#     269     http_options = HttpOptions(base_url=base_url)
# --> 271 self._api_client = self._get_api_client(
#     272     vertexai=vertexai,
#     273     api_key=api_key,
#     274     credentials=credentials,
#     275     project=project,
# ...

# %%
from google import genai

client = genai.Client('AIzaSyDwcXOje45ln8ScNQZvK3HxOhD8CQsAPJ8')  # Auto-detects env var
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Write a haiku about Python programming."
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 from google import genai
# ----> 3 client = genai.Client('AIzaSyDwcXOje45ln8ScNQZvK3HxOhD8CQsAPJ8')  # Auto-detects env var
#       4 response = client.models.generate_content(
#       5     model="gemini-2.5-flash",
#       6     contents="Write a haiku about Python programming."
#       7 )
#       8 print(response.text)
#
# TypeError: Client.__init__() takes 1 positional argument but 2 were given

# %%
import os
print("GOOGLE_API_KEY:", os.getenv("GOOGLE_API_KEY"))
print("GEMINI_API_KEY:", os.getenv("GEMINI_API_KEY"))
# Out:
# GOOGLE_API_KEY: None
# GEMINI_API_KEY: None

# %%
import os

for name, value in os.environ.items():
    print(f"{name} = {value}")
# Out:
# COMMAND_MODE = unix2003
# CONDA_DEFAULT_ENV = base
# CONDA_EXE = /opt/anaconda3/bin/conda
# CONDA_PREFIX = /opt/anaconda3
# CONDA_PROMPT_MODIFIER = (base)
# CONDA_PYTHON_EXE = /opt/anaconda3/bin/python
# CONDA_SHLVL = 1
# GSETTINGS_SCHEMA_DIR = /opt/anaconda3/share/glib-2.0/schemas
# HOME = /Users/vj
# HOMEBREW_CELLAR = /opt/homebrew/Cellar
# HOMEBREW_PREFIX = /opt/homebrew
# HOMEBREW_REPOSITORY = /opt/homebrew
# INFOPATH = /opt/homebrew/share/info:
# LANG = C.UTF-8
# LOGNAME = vj
# MANPATH = /opt/homebrew/share/man::
# MallocNanoZone = 0
# OLDPWD = /
# ORIGINAL_XDG_CURRENT_DESKTOP = undefined
# OSLogRateLimit = 64
# ...
